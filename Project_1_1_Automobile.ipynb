# %% [markdown]
# <a href="https://colab.research.google.com/github/abhangvipul/Data-Analytics/blob/main/Project_1_1_Automobile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA - Automobile
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** - Vipul Abhang

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project delivers an end-to-end data science pipeline built using the Automobile dataset. The core objective is twofold: engineering a highly precise predictive engine for vehicle pricing and building an algorithmic assessment system for insurance risk classification (symboling).
#
# Through rigorous exploratory data analysis (EDA), statistical validation, and robust preprocessing, this solution addresses data inconsistencies, missing values, and non-linear feature relationships.
#
# The final system equips manufacturers, dealerships, and insurance underwriters with data-backed frameworks to optimize pricing models, mitigate underwriting risks, and drive asset-allocation strategies.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/abhangvipul/Data-Analytics/blob/main/Project_1_1_Automobile.ipynb

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The core problem statement is to predict a vehicle's market price and classify its insurance risk using mechanical specifications.
#
# 1. Price Prediction (Regression)Goal: Predict retail value.Inputs: Horsepower, engine size, weight.Impact: Automates vehicle appraisals.
#
# 2. Risk Assessment (Classification)Goal: Predict risk rating.Target: The symboling column.Impact: Minimizes underwriting losses.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
path = '/content/drive/MyDrive/Data Analytics/Data Set/automobile_data.csv'
df = pd.read_csv(path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (205, 26)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
#df['symboling'].value_counts()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The Dataset is having some Automobile data.
# It is having 205 rows and 26 columns.
# It is having 5 float64, 5 int64 and 16 object data-types.
# It is not having any duplicate value as well as Null values in it.
# These columns are divided into four logical categories:
# 1. Risk & Identification
# 2. Brand & Marketing
# 3. Mechanical Specifications
# 4. Performance & Target

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# symboling          int64
#
# normalized-losses  object
#
# make               object
#
# fuel-type          object
#
# aspiration         object
#
# num-of-doors       object
#
# body-style         object
#
# drive-wheels       object
#
# engine-location    object
#
# wheel-base         float64
#
# length             float64
#
# width              float64
#
# height             float64
#
# curb-weight        int64
#
# engine-type        object
#
# num-of-cylinders   object
#
# engine-size        int64
#
# fuel-system        object
#
# bore               object
#
# stroke             object
#
# compression-ratio  float64
#
# horsepower         object
#
# peak-rpm           object
#
# city-mpg           int64
#
# highway-mpg        int64
#
# price              object

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
df.nunique()
# Out:
# symboling              6
# normalized-losses     52
# make                  22
# fuel-type              2
# aspiration             2
# num-of-doors           3
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            53
# length                75
# width                 44
# height                49
# curb-weight          171
# engine-type            7
# num-of-cylinders       7
# engine-size           44
# fuel-system            8
# bore                  39
# stroke                37
# compression-ratio     32
# horsepower            60
# peak-rpm              24
# city-mpg              29
# highway-mpg           30
# price                187
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
print((df == '?').any())
# Out:
# symboling            False
# normalized-losses     True
# make                 False
# fuel-type            False
# aspiration           False
# num-of-doors          True
# body-style           False
# drive-wheels         False
# engine-location      False
# wheel-base           False
# length               False
# width                False
# height               False
# curb-weight          False
# engine-type          False
# num-of-cylinders     False
# engine-size          False
# fuel-system          False
# bore                  True
# stroke                True
# compression-ratio    False
# horsepower            True
# peak-rpm              True
# city-mpg             False
# highway-mpg          False
# price                 True
# dtype: bool

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# %%
df.head(12)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
mean_price = df['price'].mean()
mean_price
# Out:
# np.float64(13207.129353233831)

# %%
df['price'].fillna(mean_price, inplace=True)
# Out:
# /tmp/ipykernel_407/889062095.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['price'].fillna(mean_price, inplace=True)

# %%
df.head(12)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
df['price'] = df['price'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df['normalized-losses'] = pd.to_numeric(df['normalized-losses'], errors='coerce')

# %%
median_normalized_losses = df['normalized-losses'].median()
median_normalized_losses
# Out:
# 115.0

# %%
df['normalized-losses'].fillna(value=median_normalized_losses, inplace=True)
# Out:
# /tmp/ipykernel_407/3558130812.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['normalized-losses'].fillna(value=median_normalized_losses, inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              115.0  alfa-romero       gas        std
# 1          3              115.0  alfa-romero       gas        std
# 2          1              115.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
print((df == '?').any())
# Out:
# symboling            False
# normalized-losses    False
# make                 False
# fuel-type            False
# aspiration           False
# num-of-doors          True
# body-style           False
# drive-wheels         False
# engine-location      False
# wheel-base           False
# length               False
# width                False
# height               False
# curb-weight          False
# engine-type          False
# num-of-cylinders     False
# engine-size          False
# fuel-system          False
# bore                  True
# stroke                True
# compression-ratio    False
# horsepower            True
# peak-rpm              True
# city-mpg             False
# highway-mpg          False
# price                False
# dtype: bool

# %%
df['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    114
# two      89
# ?         2
# Name: count, dtype: int64

# %%
num_door_mode = df['num-of-doors'].mode()
num_door_mode
# Out:
# 0    four
# Name: num-of-doors, dtype: object

# %%
df['num-of-doors'].replace(to_replace='?', value='four', inplace=True)
# Out:
# /tmp/ipykernel_407/2870490909.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['num-of-doors'].replace(to_replace='?', value='four', inplace=True)

# %%
df['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    116
# two      89
# Name: count, dtype: int64

# %%
print((df == '?').any())
# Out:
# symboling            False
# normalized-losses    False
# make                 False
# fuel-type            False
# aspiration           False
# num-of-doors         False
# body-style           False
# drive-wheels         False
# engine-location      False
# wheel-base           False
# length               False
# width                False
# height               False
# curb-weight          False
# engine-type          False
# num-of-cylinders     False
# engine-size          False
# fuel-system          False
# bore                  True
# stroke                True
# compression-ratio    False
# horsepower            True
# peak-rpm              True
# city-mpg             False
# highway-mpg          False
# price                False
# dtype: bool

# %%
df['bore'].value_counts()
# Out:
# bore
# 3.62    23
# 3.19    20
# 3.15    15
# 3.03    12
# 2.97    12
# 3.46     9
# 3.31     8
# 3.43     8
# 3.78     8
# 3.27     7
# 2.91     7
# 3.58     6
# 3.05     6
# 3.54     6
# 3.39     6
# 3.7      5
# 3.01     5
# 3.35     4
# ?        4
# 3.74     3
# 3.17     3
# 3.59     3
# 3.5      2
# 3.24     2
# 3.13     2
# 3.47     2
# 3.94     2
# 3.8      2
# 3.63     2
# 3.33     2
# 2.68     1
# 3.76     1
# 3.08     1
# 2.92     1
# 3.6      1
# 3.34     1
# 2.99     1
# 2.54     1
# 3.61     1
# Name: count, dtype: int64

# %%
df['bore'] = pd.to_numeric(df['bore'], errors='coerce')

# %%
df['bore'].median()
# Out:
# 3.31

# %%
df[55:60]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 55          3              150.0  mazda       gas        std          two
# 56          3              150.0  mazda       gas        std          two
# 57          3              150.0  mazda       gas        std          two
# 58          3              150.0  mazda       gas        std          two
# 59          1              129.0  mazda       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 55  hatchback          rwd           front        95.3  ...           70
# 56  hatchback          rwd           front        95.3  ...           70
# 57  hatchback          rwd           front        95.3  ...           70
# 58  hatchback          rwd           front        95.3  ...           80
# 59  hatchback          fwd           front        98.8  ...          122
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# ...

# %%
median_bore = df['bore'].median()
median_bore
# Out:
# 3.31

# %%
df['bore'].fillna(value=median_bore, inplace=True)
# Out:
# /tmp/ipykernel_407/1287411941.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['bore'].fillna(value=median_bore, inplace=True)

# %%
df[55:60]
# Out:
#     symboling  normalized-losses   make fuel-type aspiration num-of-doors  \
# 55          3              150.0  mazda       gas        std          two
# 56          3              150.0  mazda       gas        std          two
# 57          3              150.0  mazda       gas        std          two
# 58          3              150.0  mazda       gas        std          two
# 59          1              129.0  mazda       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 55  hatchback          rwd           front        95.3  ...           70
# 56  hatchback          rwd           front        95.3  ...           70
# 57  hatchback          rwd           front        95.3  ...           70
# 58  hatchback          rwd           front        95.3  ...           80
# 59  hatchback          fwd           front        98.8  ...          122
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# ...

# %%
print((df == '?').any())
# Out:
# symboling            False
# normalized-losses    False
# make                 False
# fuel-type            False
# aspiration           False
# num-of-doors         False
# body-style           False
# drive-wheels         False
# engine-location      False
# wheel-base           False
# length               False
# width                False
# height               False
# curb-weight          False
# engine-type          False
# num-of-cylinders     False
# engine-size          False
# fuel-system          False
# bore                 False
# stroke                True
# compression-ratio    False
# horsepower            True
# peak-rpm              True
# city-mpg             False
# highway-mpg          False
# price                False
# dtype: bool

# %%
df['stroke'].value_counts()
# Out:
# stroke
# 3.4     20
# 3.23    14
# 3.15    14
# 3.03    14
# 3.39    13
# 2.64    11
# 3.35     9
# 3.29     9
# 3.46     8
# 3.58     6
# 3.11     6
# 3.07     6
# 3.19     6
# 3.27     6
# 3.41     6
# 3.5      6
# 3.52     5
# 3.64     5
# 3.86     4
# 3.47     4
# ?        4
# 3.54     4
# 2.9      3
# 3.9      3
# 2.68     2
# 2.8      2
# 3.08     2
# 4.17     2
# 3.1      2
# 2.19     2
# 2.76     1
# 3.16     1
# 3.12     1
# 3.21     1
# 2.07     1
# 2.36     1
# 2.87     1
# Name: count, dtype: int64

# %%
df['horsepower'].value_counts()
# Out:
# horsepower
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 88      6
# 114     6
# 62      6
# 101     6
# 160     6
# 102     5
# 76      5
# 97      5
# 82      5
# 145     5
# 84      5
# 123     4
# 86      4
# 92      4
# 111     4
# 121     3
# 90      3
# 182     3
# 85      3
# 73      3
# 152     3
# 207     3
# 112     2
# 56      2
# 156     2
# 161     2
# 52      2
# 162     2
# ?       2
# 155     2
# 100     2
# 94      2
# 184     2
# 176     2
# 115     1
# 154     1
# 140     1
# 48      1
# 120     1
# 64      1
# 135     1
# 262     1
# 78      1
# 60      1
# 58      1
# 55      1
# 288     1
# 143     1
# 142     1
# 200     1
# 175     1
# 72      1
# 134     1
# 106     1
# Name: count, dtype: int64

# %%
df['peak-rpm'].value_counts()
# Out:
# peak-rpm
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# 6000     9
# 4500     7
# 5800     7
# 5250     7
# 4200     5
# 4150     5
# 4750     4
# 4350     4
# 4250     3
# 5100     3
# 5900     3
# 4400     3
# ?        2
# 6600     2
# 4650     1
# 5600     1
# 5750     1
# 4900     1
# 5300     1
# Name: count, dtype: int64

# %%
df['stroke'] = pd.to_numeric(df['stroke'], errors='coerce')
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df['peak-rpm'] = pd.to_numeric(df['peak-rpm'], errors='coerce')

# %%
median_stroke = df['stroke'].median()
median_stroke
# Out:
# 3.29

# %%
median_horsepower = df['horsepower'].median()
median_horsepower
# Out:
# 95.0

# %%
median_peak_rpm = df['peak-rpm'].median()
median_peak_rpm
# Out:
# 5200.0

# %%
df['stroke'].fillna(value=median_stroke, inplace=True)
# Out:
# /tmp/ipykernel_407/60810480.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['stroke'].fillna(value=median_stroke, inplace=True)

# %%
df['horsepower'].fillna(value=median_horsepower, inplace=True)
# Out:
# /tmp/ipykernel_407/3015122764.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['horsepower'].fillna(value=median_horsepower, inplace=True)

# %%
df['peak-rpm'].fillna(value=median_peak_rpm, inplace=True)
# Out:
# /tmp/ipykernel_407/121742841.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['peak-rpm'].fillna(value=median_peak_rpm, inplace=True)

# %%
print((df == '?').any())
# Out:
# symboling            False
# normalized-losses    False
# make                 False
# fuel-type            False
# aspiration           False
# num-of-doors         False
# body-style           False
# drive-wheels         False
# engine-location      False
# wheel-base           False
# length               False
# width                False
# height               False
# curb-weight          False
# engine-type          False
# num-of-cylinders     False
# engine-size          False
# fuel-system          False
# bore                 False
# stroke               False
# compression-ratio    False
# horsepower           False
# peak-rpm             False
# city-mpg             False
# highway-mpg          False
# price                False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              115.0  alfa-romero       gas        std
# 1          3              115.0  alfa-romero       gas        std
# 2          1              115.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The Datatype of price, normalized-losses,bore,stroke, horsepower, peak-rpm columns are object. That was converted to numeric datatype. After converting it the value ? from these columns are replaced by the mean and median.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
make_cars = df['make'].value_counts().sort_values(ascending=False)
make_cars
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# alfa-romero       3
# chevrolet         3
# jaguar            3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,3))
make_cars.plot(kind='bar', color = sns.color_palette('Set2'))
plt.title('Make Type')
plt.xlabel('Make')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is the ideal choice for this step becaus visualizes the distribution of car brands (Make) and its value count analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Based on the visualization of the car brand frequencies, here are the key insights found from the chart:
# Top Brand: Toyota is by far the most dominant brand in the dataset, with over 30 vehicles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Dealerships or parts distributors can maximize turnover by stocking high-volume brands like Toyota, Nissan, and Mazda.
#
# The Insight: High-end luxury or performance brands like Porsche, Jaguar, and BMW appear at the bottom with very low counts.
#
# Negative Impact: A business might mistakenly phase these brands out. In reality, while these brands have low sales volume, they carry extremely high profit margins. Ignoring them means leaving significant revenue on the table.

# %% [markdown]
# #### Chart - 2

# %%
make_fuel_type = df.groupby(['make', 'fuel-type'])['fuel-type'].value_counts().sort_values(ascending=False).unstack()
make_fuel_type
# Out:
# fuel-type      diesel   gas
# make
# alfa-romero       NaN   3.0
# audi              NaN   7.0
# bmw               NaN   8.0
# chevrolet         NaN   3.0
# dodge             NaN   9.0
# honda             NaN  13.0
# isuzu             NaN   4.0
# jaguar            NaN   3.0
# mazda             2.0  15.0
# mercedes-benz     4.0   4.0
# mercury           NaN   1.0
# mitsubishi        NaN  13.0
# nissan            1.0  17.0
# peugot            5.0   6.0
# plymouth          NaN   7.0
# porsche           NaN   5.0
# renault           NaN   2.0
# saab              NaN   6.0
# subaru            NaN  12.0
# toyota            3.0  29.0
# volkswagen        4.0   8.0
# volvo             1.0  10.0

# %%
plt.figure(figsize=(9,3))
make_fuel_type.plot(kind='bar', stacked=True, width=0.8, color = sns.color_palette('Set2'))
plt.title('Makewise Fuel Type')
plt.xlabel('Make')
plt.ylabel('Fuel Type Count')
# Out:
# Text(0, 0.5, 'Fuel Type Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# stacking the bars preserves the total volume of cars for each brand, allowing you to simultaneously compare overall brand popularity and internal fuel proportions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Gasoline is overwhelmingly the dominant fuel type across almost all manufacturers. Many brands (like Honda, Subaru, BMW, and Mitsubishi) feature gas vehicles exclusively in this dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Service centers and parts distributors can optimize operations. For example, a shop located in a region dominated by Peugeots or Mercedes-Benz vehicles must heavily stock diesel filters, specialized oils, and glow plugs

# %%
max_price = df.groupby(['make'])['price'].max().sort_values(ascending=False)
max_price
# Out:
# make
# mercedes-benz    45400
# bmw              41315
# porsche          37028
# jaguar           36000
# audi             23875
# volvo            22625
# nissan           19699
# saab             18620
# mazda            18344
# peugot           18150
# toyota           17669
# mercury          16503
# alfa-romero      16500
# mitsubishi       14869
# volkswagen       13845
# isuzu            13207
# dodge            12964
# honda            12945
# plymouth         12764
# subaru           11694
# renault           9895
# chevrolet         6575
# Name: price, dtype: int64

# %%
plt.figure(figsize=(9,3))
max_price.plot(kind='bar', color = sns.color_palette('Set2'))
plt.title('Makewise Max Price')
plt.xlabel('Make')
plt.ylabel('Max Price')
# Out:
# Text(0, 0.5, 'Max Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A vertical bar chart is the most effective way to compare a specific metric across multiple discrete categories

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Mercedes-Benz has the highest maximum vehicle price in the dataset (exceeding 45,000), closely followed by BMW.
# The majority of the brands (14 out of 22) are capped between  10,000 and  20,000, indicating highly competitive mass-market positioning.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive/Negative business impact? Justify.

# %% [markdown]
# Dealerships and manufacturers can use this data to correctly position competitive marketing campaigns.

# %%
mean_price = df.groupby('make')['price'].mean().sort_values(ascending=False)
mean_price
# Out:
# make
# jaguar           34600.000000
# mercedes-benz    33647.000000
# porsche          27761.800000
# bmw              26118.750000
# volvo            18063.181818
# audi             17194.571429
# mercury          16503.000000
# alfa-romero      15498.333333
# peugot           15489.090909
# saab             15223.333333
# isuzu            11061.750000
# mazda            10652.882353
# nissan           10415.666667
# volkswagen       10077.500000
# toyota            9885.812500
# renault           9595.000000
# mitsubishi        9239.769231
# subaru            8541.250000
# honda             8184.692308
# plymouth          7963.428571
# dodge             7875.444444
# chevrolet         6007.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(9,3))
mean_price.plot(kind='bar', color = sns.color_palette('Set2'))
plt.title('Makewise Mean Price')
plt.xlabel('Make')
plt.ylabel('Mean Price')
# Out:
# Text(0, 0.5, 'Mean Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A vertical bar chart cleanly illustrates the average (mean) pricing tier for each manufacturer.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Jaguar takes the top spot for the highest mean price (around $35,000), even though Mercedes-Benz had the higher single maximum vehicle price. This indicates Jaguar's entire lineup is consistently expensive.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive/Negative business impact? Justify.

# %% [markdown]
# Dealerships can confidently structure their financing and floor planning. Knowing Jaguar has the highest mean price proves that stocking any Jaguar requires more capital but promises a higher typical return per unit sold compared to a brand with volatile individual pricing.

# %%
min_price = df.groupby(['make'])['price'].min().sort_values(ascending=True)
min_price
# Out:
# make
# subaru            5118
# chevrolet         5151
# mazda             5195
# toyota            5348
# mitsubishi        5389
# honda             5399
# nissan            5499
# plymouth          5572
# dodge             5572
# isuzu             6785
# volkswagen        7775
# renault           9295
# saab             11850
# peugot           11900
# volvo            12940
# porsche          13207
# audi             13207
# alfa-romero      13495
# bmw              16430
# mercury          16503
# mercedes-benz    25552
# jaguar           32250
# Name: price, dtype: int64

# %%
plt.figure(figsize=(9,3))
min_price.plot(kind='bar', color = sns.color_palette('Set2'))
plt.title('Makewise Min Price')
plt.xlabel('Make')
plt.ylabel('Min Price')
# Out:
# Text(0, 0.5, 'Min Price')

# %%
make_body_style = df.groupby(['make', 'body-style'])['body-style'].value_counts().sort_values(ascending=False).head(10)
make_body_style
# Out:
# make        body-style
# toyota      hatchback     14
# mazda       hatchback     10
# toyota      sedan         10
# mitsubishi  hatchback      9
# nissan      sedan          9
# volkswagen  sedan          9
# volvo       sedan          8
# bmw         sedan          8
# honda       hatchback      7
# peugot      sedan          7
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,3))
make_body_style.plot(kind='bar', color = sns.color_palette('Set2'))
plt.title('Makewise Body Style')
plt.xlabel('Make')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A vertical bar chart is chosen to display discrete combinations of (make, body-style) on the x-axis against a numerical metric on the y-axis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Out of the top 10 visible categories, 6 out of 10 are sedans, showing that sedans make up the majority of this specific high-value list.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive/Negative business impact? Justify.

# %% [markdown]
# A positive impact is justified because it prevents a company from overpricing entry-level models relative to market giants like Toyota.

# %%
make_no_doors = df.groupby(['make', 'num-of-doors'])['num-of-doors'].value_counts().sort_values(ascending=False).unstack()
make_no_doors
# Out:
# num-of-doors   four   two
# make
# alfa-romero     NaN   3.0
# audi            5.0   2.0
# bmw             5.0   3.0
# chevrolet       1.0   2.0
# dodge           5.0   4.0
# honda           5.0   8.0
# isuzu           2.0   2.0
# jaguar          2.0   1.0
# mazda           8.0   9.0
# mercedes-benz   5.0   3.0
# mercury         NaN   1.0
# mitsubishi      4.0   9.0
# nissan          9.0   9.0
# peugot         11.0   NaN
# plymouth        4.0   3.0
# porsche         NaN   5.0
# renault         1.0   1.0
# saab            3.0   3.0
# subaru          9.0   3.0
# toyota         18.0  14.0
# volkswagen      8.0   4.0
# volvo          11.0   NaN

# %%
plt.figure(figsize=(9,3))
make_no_doors.plot(kind='bar', stacked=True, width= 0.8, color = sns.color_palette('Set2'))
plt.title('Makewise No of Doors')
plt.xlabel('Make')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Placing the categories vertically within a single bar makes it easy to compare the proportion of door configurations across different car brands without needing separate charts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Toyota is overwhelmingly dominant in this dataset, with a total count exceeding 30 vehicles. It also has the highest individual volume for both four-door and two-door cars.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive/Negative business impact?

# %% [markdown]
# The insights from this chart will drive a positive business impact by informing fleet planning, production balancing, and supply chain logistics.

# %%
fueltype = df['fuel-type'].value_counts()
fueltype
# Out:
# fuel-type
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,3))
fueltype.plot(kind='pie', autopct='%1.1f%%', startangle=0, ylabel='', color = sns.color_palette('Set2'))
plt.title('Fuelwise Vehicle Share')
#plt.xlabel('Fuel Type')
#plt.ylabel('Count')
# Out:
# Text(0.5, 1.0, 'Fuelwise Vehicle Share')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is selected to show the part-to-whole relationship of a categorical variable with very few groups (only two categories: gas and diesel).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Overwhelming Gas Dominance: Vehicles running on gas make up the vast majority of the fleet or dataset, accounting for roughly 85% to 90% of the total share.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# An automotive business (like a parts distributor or service center) can confidently allocate 85%+ of its budget, shelf space, and technician training toward gas engine components, avoiding cash flow tie-up in slow-moving diesel inventory.

# %%
df['avg_mpg'] = (df['city-mpg'] + df['highway-mpg']) / 2

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              115.0  alfa-romero       gas        std
# 1          3              115.0  alfa-romero       gas        std
# 2          1              115.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
brand_avg_mpg = df.groupby('make')['avg_mpg'].mean().sort_values(ascending=False).head(10)
brand_avg_mpg
# Out:
# make
# chevrolet     43.666667
# isuzu         33.500000
# honda         32.923077
# volkswagen    31.750000
# plymouth      31.142857
# dodge         31.055556
# toyota        30.203125
# nissan        29.972222
# mazda         28.823529
# subaru        28.541667
# Name: avg_mpg, dtype: float64

# %%
plt.figure(figsize=(9,3))
brand_avg_mpg.plot(kind='bar', x='make', y='avg_mpg', color = sns.color_palette('Set2'))
plt.title('Fuelwise avg')
plt.xlabel('Make')
plt.ylabel('Avg')
# Out:
# Text(0, 0.5, 'Avg')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This grouped vertical bar chart is the perfect choice because it consolidates the data to show a single, unique average value per manufacturer, eliminating the repeated rows from the previous iteration.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# When averaging across all models in the dataset, Chevrolet holds a distinct and commanding lead, with a true brand average of nearly 44 MPG.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Corporate purchasing managers or rental car fleets can use this data to make bulk buying decisions. Instead of hunting for rare individual model specs, they can confidently sign fleet contracts with Chevrolet, knowing the brand's overall portfolio delivers superior fuel economy.

# %%
body_style = df['body-style'].value_counts()
body_style
# Out:
# body-style
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
explode_values = [0, 0, 0, 0.15, 0.15]
plt.figure(figsize=(9,3))
body_style.plot(kind='pie', autopct='%1.1f%%', startangle=0, ylabel='', color = sns.color_palette('Set2'),explode=explode_values, shadow=True)
plt.title('Body Style')
#plt.xlabel('Style')
#plt.ylabel('Count')
# Out:
# Text(0.5, 1.0, 'Body Style')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The circular slices allow the audience to instantly grasp relative market share without needing to read raw numerical values or look at a secondary scale axis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Primary Duo: Together, sedans and hatchbacks (34.1%) dominate the market, accounting for a massive 80.9% of all vehicles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Automakers or parts suppliers can optimize their operations by dedicating over 80% of their floor space, engineering resources, and factory tooling to sedan and hatchback components.

# %%
make_price_horsepower = df.groupby(['make', 'price'])['horsepower'].mean().sort_values(ascending=False).head(10)
make_price_horsepower
# Out:
# make           price
# porsche        13207    288.0
# jaguar         36000    262.0
# porsche        37028    207.0
#                32528    207.0
#                34028    207.0
# nissan         19699    200.0
# mercedes-benz  40960    184.0
#                45400    184.0
# bmw            41315    182.0
#                36880    182.0
# Name: horsepower, dtype: float64

# %%
plt.figure(figsize=(9,3))
make_price_horsepower.plot(kind='bar', color = sns.color_palette('Set2'))
plt.title('Make, Price and Horsepower')
plt.xlabel('Make')
plt.ylabel('Horsepower')
# Out:
# Text(0, 0.5, 'Horsepower')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A vertical bar chart is chosen here because it allows a straightforward, descending visual ranking of the top 10 discrete vehicle configurations based on their exact horsepower values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Out of the top 10 highest-horsepower variations, 9 out of 10 belong to luxury/premium marques: Porsche (4 entries), Mercedes-Benz (2 entries), BMW (2 entries), and Jaguar (1 entry).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# The impact is positive because it gives premium brands empirical boundaries. For instance, BMW and Mercedes-Benz can see exactly where their premium models sit relative to performance rivals, ensuring they do not overprice lower-horsepower variants in highly competitive segments.

# %%
make_body_price = df.groupby(['make', 'body-style'])['price'].mean().sort_values(ascending=False).head(10)
make_body_price
# Out:
# make           body-style
# porsche        convertible    37028.000
# mercedes-benz  hardtop        36788.000
#                convertible    35056.000
# jaguar         sedan          34600.000
# porsche        hardtop        33278.000
# mercedes-benz  sedan          33074.000
#                wagon          28248.000
# bmw            sedan          26118.750
# audi           wagon          18920.000
# volvo          sedan          18726.875
# Name: price, dtype: float64

# %%
plt.figure(figsize=(9,3))
make_body_price.plot(kind='bar', color = sns.color_palette('Set2'))
plt.title('Make')
plt.xlabel('Body Style')
plt.ylabel('Avg Price')
# Out:
# Text(0, 0.5, 'Avg Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A vertical bar chart is chosen here because it allows a straightforward, descending visual ranking of the top 10 discrete vehicle configurations based on their average market price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most expensive segments are dominated by luxury sports configurations, with a Porsche convertible leading the chart at an average price of roughly $37,000, closely followed by a Mercedes-Benz hardtop.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# For premium dealerships or manufacturers, this graph shows exactly where the highest gross margins reside. Prioritizing the acquisition or production of convertibles and hardtops for Porsche and Mercedes-Benz maximizes the average transaction value.

# %%
make_fuel_price = df.groupby(['make','fuel-type'])['price'].mean().sort_values(ascending=False).head(10)
make_fuel_price
# Out:
# make           fuel-type
# mercedes-benz  gas          38900.000000
# jaguar         gas          34600.000000
# mercedes-benz  diesel       28394.000000
# porsche        gas          27761.800000
# bmw            gas          26118.750000
# volvo          diesel       22470.000000
#                gas          17622.500000
# audi           gas          17194.571429
# mercury        gas          16503.000000
# peugot         diesel       15797.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(9,3))
make_fuel_price.plot(kind='bar', color = sns.color_palette('Set2'))
plt.title('Make, Fuel Type and Price')
plt.xlabel('Make, Fuel Type')
plt.ylabel('Avg Price')
# Out:
# Text(0, 0.5, 'Avg Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A vertical bar chart is chosen to display a descending visual hierarchy of the top 10 average prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A gas-powered Mercedes-Benz holds the highest average price tier, approaching nearly $39,000.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Mercedes-Benz dealerships can maximize profits by prioritizing gas configurations over diesel models.

# %%
make_price = df.groupby('make')['price'].mean().sort_values(ascending=False).head(10)
make_price
# Out:
# make
# jaguar           34600.000000
# mercedes-benz    33647.000000
# porsche          27761.800000
# bmw              26118.750000
# volvo            18063.181818
# audi             17194.571429
# mercury          16503.000000
# alfa-romero      15498.333333
# peugot           15489.090909
# saab             15223.333333
# Name: price, dtype: float64

# %%
plt.figure(figsize=(9,3))
make_price.plot(kind='bar', color = sns.color_palette('Set2'))
plt.title('Make Style')
plt.xlabel('Make')
plt.ylabel('Avg Price')
# Out:
# Text(0, 0.5, 'Avg Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A vertical bar chart is chosen here because it maps unique categorical entities (Make) along the x-axis against a single aggregated numerical metric (Avg Price) on the y-axis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Premium Tier Duo: Jaguar leads the entire dataset with the highest average price (approx. 34,500), closely followed by Mercedes-Benz (approx. 33,500).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Dealership networks or auto-retail groups can establish precise showroom pricing bands. They know they can market Jaguar and Mercedes-Benz as ultra-premium anchors, while positioning Volvo, Audi, and Saab as competitive, high-volume options for aspirational buyers.

# %%
make_drive_price = df.groupby(['make','drive-wheels'])['price'].mean().sort_values(ascending=False).unstack()
make_drive_price
# Out:
# drive-wheels       4wd           fwd           rwd
# make
# alfa-romero        NaN           NaN  15498.333333
# audi           15328.5  17941.000000           NaN
# bmw                NaN           NaN  26118.750000
# chevrolet          NaN   6007.000000           NaN
# dodge              NaN   7875.444444           NaN
# honda              NaN   8184.692308           NaN
# isuzu              NaN  13207.000000   8916.500000
# jaguar             NaN           NaN  34600.000000
# mazda              NaN   8399.545455  14784.000000
# mercedes-benz      NaN           NaN  33647.000000
# mercury            NaN           NaN  16503.000000
# mitsubishi         NaN   9239.769231           NaN
# nissan             NaN   8812.333333  18432.333333
# peugot             NaN           NaN  15489.090909
# plymouth           NaN   7163.333333  12764.000000
# porsche            NaN           NaN  27761.800000
# renault            NaN   9595.000000           NaN
# ...

# %%
plt.figure(figsize=(15,3))
ax = make_drive_price.plot(kind='bar',  width=0.8, color = sns.color_palette('Set2'),ax=plt.gca() )   # Attaches the plot to the active figure size)
plt.title('Make, Drive-Wheels')
plt.xlabel('Make')
plt.ylabel('Avg Price')
# Out:
# Text(0, 0.5, 'Avg Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  It allows stakeholders to contrast different drivetrain configurations (4wd, fwd, rwd) side-by-side within the exact same vehicle manufacturer.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Luxury Rear-Wheel Drive (rwd) Premium: Rear-wheel drive (rwd, purple bars) is exclusively utilized by the most expensive brands or acts as the premium anchor within mixed brands. Jaguar and Mercedes-Benz lead the chart at roughly 33,000–35,000, while BMW and Porsche also rely purely on high-value rwd entries.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# A positive impact is mathematically justified because buying teams can avoid major margin errors. Sourcing managers looking at Audi know that stocking fwd and 4wd variants yields roughly similar premium returns (~$15k–$18k), whereas stocking a fwd version of a brand like Mazda yields far less capital return than its premium rwd counterpart.

# %%
make_cylinder_price = df.groupby(['make','num-of-cylinders'])['price'].mean().sort_values(ascending=False).unstack()
make_cylinder_price
# Out:
# num-of-cylinders    eight          five          four           six   three  \
# make
# alfa-romero           NaN           NaN  14997.500000  16500.000000     NaN
# audi                  NaN  17735.333333  13950.000000           NaN     NaN
# bmw                   NaN           NaN  16677.500000  29265.833333     NaN
# chevrolet             NaN           NaN   6435.000000           NaN  5151.0
# dodge                 NaN           NaN   7875.444444           NaN     NaN
# honda                 NaN           NaN   8184.692308           NaN     NaN
# isuzu                 NaN           NaN  11061.750000           NaN     NaN
# jaguar                NaN           NaN           NaN  33900.000000     NaN
# mazda                 NaN           NaN   9924.538462           NaN     NaN
# mercedes-benz     38900.0  28394.000000           NaN           NaN     NaN
# mercury               NaN           NaN  16503.000000           NaN     NaN
# ...

# %%
plt.figure(figsize=(14,4))
ax = make_cylinder_price.plot(kind='bar', width=2, color = sns.color_palette('Set2'),ax=plt.gca())
plt.title('No of Cylinder Vs Price')
plt.xlabel('Make ')
plt.ylabel('Avg Price')
# Out:
# Text(0, 0.5, 'Avg Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It allows stakeholders to look within a single brand (like Jaguar, Mazda, or Porsche) and directly evaluate how price premiums scale alongside engine cylinder upgrades.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The High-End Performance Elite: Mazda holds the single highest average price configuration in this specific view with its eight cylinder engine (teal bar) reaching nearly $39,000, closely followed by its five cylinder variant.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Dealerships and sales teams can use this data to map out clear up-selling tiers. For instance, looking at BMW or Volvo, there is a massive, visible price jump when transitioning from a standard 4-cylinder to a premium 6-cylinder engine. Sales training can be optimized to focus on the performance benefits that justify this precise margin leap.

# %%
make_enginetype_price = df.groupby(['make','engine-type'])['price'].mean().sort_values(ascending=False).head(20).unstack()
make_enginetype_price
# Out:
# engine-type            dohc    dohcv             l           ohc     ohcf  \
# make
# mercedes-benz           NaN      NaN           NaN  28394.000000      NaN
# jaguar         33900.000000      NaN           NaN           NaN      NaN
# porsche                 NaN  13207.0           NaN  22018.000000  34528.0
# bmw                     NaN      NaN           NaN  26118.750000      NaN
# volvo                   NaN      NaN           NaN  17721.000000      NaN
# saab           18385.000000      NaN           NaN  13642.500000      NaN
# audi                    NaN      NaN           NaN  17194.571429      NaN
# mercury                 NaN      NaN           NaN  16503.000000      NaN
# alfa-romero    14997.500000      NaN           NaN           NaN      NaN
# nissan                  NaN      NaN           NaN           NaN      NaN
# peugot                  NaN      NaN  15489.090909           NaN      NaN
# toyota         13805.333333      NaN           NaN           NaN      NaN
# ...

# %%
plt.figure(figsize=(14,5))
ax = make_enginetype_price.plot(kind='bar', width=1.80, color = sns.color_palette('Set2'),ax=plt.gca())
plt.title('Engine Type, Make n Price')
plt.xlabel('Make ')
plt.ylabel('Avg Price')
# Out:
# Text(0, 0.5, 'Avg Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This layout allows direct visual comparisons of how completely different valvetrain architectures (ohc, ohcv, dohc, etc.) map to true price premiums within a single car manufacturer.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The High-End Engineering Tier: Overhead cam configurations with a V-architecture (ohcv, yellow bars) dominate the absolute highest pricing tiers. This layout commands approximately 39,000 for Mercedes-Benz and 36,000 for Jaguar.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
#  For automakers or tier-1 engine parts suppliers, this chart provides an empirical map of customer willingness-to-pay. Seeing that an ohcv setup fetches an average $10,000+ premium over a standard ohc setup within the same brand gives product development teams a clear green light to invest in complex premium architectures.

# %%
make_aspiration_price = df.groupby(['make','aspiration'])['price'].mean().sort_values(ascending=False).unstack()
make_aspiration_price
# Out:
# aspiration              std         turbo
# make
# alfa-romero    15498.333333           NaN
# audi           16656.000000  18541.000000
# bmw            26118.750000           NaN
# chevrolet       6007.000000           NaN
# dodge           6900.000000   9826.333333
# honda           8184.692308           NaN
# isuzu          11061.750000           NaN
# jaguar         34600.000000           NaN
# mazda          10652.882353           NaN
# mercedes-benz  38900.000000  28394.000000
# mercury                 NaN  16503.000000
# mitsubishi      7314.714286  11485.666667
# nissan          9869.588235  19699.000000
# peugot         14649.000000  16189.166667
# plymouth        7004.600000  10360.500000
# porsche        27761.800000           NaN
# renault         9595.000000           NaN
# saab           13642.500000  18385.000000
# subaru          7954.200000  11476.500000
# toyota          9859.612903  10698.000000
# volkswagen      9759.000000  11670.000000
# ...

# %%
plt.figure(figsize=(12,4))
ax = make_aspiration_price.plot(kind='bar', width=0.80, color = sns.color_palette('Set2'),ax = plt.gca())
plt.title('Aspiration Vs Price')
plt.xlabel('Make ')
plt.ylabel('Avg Price')
# Out:
# Text(0, 0.5, 'Avg Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It allows stakeholders to look within a single brand (like Audi, Nissan, or Volvo) and directly evaluate the exact price difference between standard (std) and turbo variants.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Consistent Turbo Premium: For almost all mid-tier and high-volume brands (such as Audi, Dodge, Mitsubishi, Nissan, Peugot, Plymouth, Saab, Subaru, Toyota, Volkswagen, and Volvo), turbo models command a higher average price than their standard counterparts.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# For mid-market brands like Nissan, Saab, or Volvo, the chart clearly justifies the pricing power of turbochargers. Dealerships and manufacturers can confidently build higher gross-profit margins into turbo trims because the market historically proves a higher willingness to pay.

# %%
make_drive_price = df.groupby(['make','drive-wheels'])['price'].mean().sort_values(ascending=False).unstack()
make_drive_price
# Out:
# drive-wheels       4wd           fwd           rwd
# make
# alfa-romero        NaN           NaN  15498.333333
# audi           15328.5  17941.000000           NaN
# bmw                NaN           NaN  26118.750000
# chevrolet          NaN   6007.000000           NaN
# dodge              NaN   7875.444444           NaN
# honda              NaN   8184.692308           NaN
# isuzu              NaN  13207.000000   8916.500000
# jaguar             NaN           NaN  34600.000000
# mazda              NaN   8399.545455  14784.000000
# mercedes-benz      NaN           NaN  33647.000000
# mercury            NaN           NaN  16503.000000
# mitsubishi         NaN   9239.769231           NaN
# nissan             NaN   8812.333333  18432.333333
# peugot             NaN           NaN  15489.090909
# plymouth           NaN   7163.333333  12764.000000
# porsche            NaN           NaN  27761.800000
# renault            NaN   9595.000000           NaN
# ...

# %%
plt.figure(figsize=(12,4))
ax = make_drive_price.plot(kind='bar',  width=1.3, color = sns.color_palette('Set2'),ax = plt.gca())
plt.title('Drive Wheels Vs Price')
plt.xlabel('Make ')
plt.ylabel('Avg Price')
# Out:
# Text(0, 0.5, 'Avg Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Brand Drivetrain Evaluation: It allows stakeholders to look within a single brand (like Audi, Toyota, or Subaru) and directly evaluate the exact price differences between 4wd, fwd, and rwd options.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Rear-wheel drive dominates luxury brands (Jaguar, Mercedes-Benz, BMW, and Porsche), capturing the highest pricing tier in the dataset (peaking at $34,500).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Targeted Regional Distribution: Dealership networks can maximize sales velocity by distributing stock based on drivetrain pricing tiers. Expensive rwd variants can be routed to premium urban hubs, while cost-efficient fwd models can fill high-volume commuter markets.
# Front-wheel drive serves as the baseline for affordable commuter brands (Chevrolet, Dodge, Honda, Mitsubishi, and Volkswagen), clustering consistently under $10,000.
# Four-wheel drive is highly specialized and rarely used, appearing visibly only within Audi, Subaru, and Toyota portfolios to target weather-ready or utility segments.

# %%
fuel_aspiration_price = df.groupby(['fuel-type', 'aspiration'])['price'].mean().sort_values(ascending=False)
fuel_aspiration_price
# Out:
# fuel-type  aspiration
# diesel     turbo         19159.153846
# gas        turbo         14554.625000
#            std           12679.422360
# diesel     std            9670.571429
# Name: price, dtype: float64

# %%
plt.figure(figsize=(9,3))
fuel_aspiration_price.plot(kind='bar', width= 0.2, color = sns.color_palette('Set2'))
plt.title('Fule Type Aspiration Vs Price')
plt.xlabel('Fule Type, Aspiration')
plt.ylabel('Avg Price')
# Out:
# Text(0, 0.5, 'Avg Price')

# %%
make_location_price = df.groupby(['make','engine-location'])['price'].mean().sort_values(ascending=False).unstack()
make_location_price
# Out:
# engine-location         front     rear
# make
# alfa-romero      15498.333333      NaN
# audi             17194.571429      NaN
# bmw              26118.750000      NaN
# chevrolet         6007.000000      NaN
# dodge             7875.444444      NaN
# honda             8184.692308      NaN
# isuzu            11061.750000      NaN
# jaguar           34600.000000      NaN
# mazda            10652.882353      NaN
# mercedes-benz    33647.000000      NaN
# mercury          16503.000000      NaN
# mitsubishi        9239.769231      NaN
# nissan           10415.666667      NaN
# peugot           15489.090909      NaN
# plymouth          7963.428571      NaN
# porsche          17612.500000  34528.0
# renault           9595.000000      NaN
# saab             15223.333333      NaN
# subaru            8541.250000      NaN
# toyota            9885.812500      NaN
# volkswagen       10077.500000      NaN
# volvo            18063.181818      NaN

# %%
plt.figure(figsize=(9,3))
make_location_price.plot(kind='bar', stacked=True, width=0.8, color = sns.color_palette('Set2'))
plt.title('Make, Engine Location Vs Price')
plt.xlabel('Make, Engine Location')
plt.ylabel('Avg Price')
# Out:
# Text(0, 0.5, 'Avg Price')

# %%
avg_horsepower_price = df.groupby(['make','avg_mpg','horsepower'])['price'].mean().sort_values(ascending=False).head(15)
avg_horsepower_price
# Out:
# make           avg_mpg  horsepower
# mercedes-benz  15.0     184.0         43180.0
# bmw            17.5     182.0         36880.0
#                19.0     182.0         36037.5
# jaguar         15.0     262.0         36000.0
# mercedes-benz  17.0     155.0         34620.0
# porsche        21.0     207.0         34528.0
# jaguar         17.0     176.0         33900.0
# mercedes-benz  23.5     123.0         28394.0
# bmw            22.5     121.0         24565.0
# audi           18.5     140.0         23875.0
# volvo          22.0     114.0         22625.0
#                26.5     106.0         22470.0
# porsche        23.0     143.0         22018.0
# volvo          20.5     134.0         21485.0
# bmw            24.5     121.0         21037.5
# Name: price, dtype: float64

# %%
plt.figure(figsize=(9,3))
avg_horsepower_price.plot(kind='bar',  color = sns.color_palette('Set2'))
plt.title('Make, Avg, Horsepower n Price')
plt.xlabel('Make, Avg, Horsepower')
plt.ylabel('Avg Price')
# Out:
# Text(0, 0.5, 'Avg Price')

# %%
sns.lmplot(x='symboling', y='normalized-losses', data=df)

# %%
df[['symboling', 'normalized-losses']].corr()
# Out:
#                    symboling  normalized-losses
# symboling           1.000000           0.457484
# normalized-losses   0.457484           1.000000

# %%
plt.figure(figsize=(9,3))
sns.heatmap(df[['symboling', 'normalized-losses']].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.regplot(x="avg_mpg", y="price", data=df)
# Out:
# <Axes: xlabel='avg_mpg', ylabel='price'>

# %%
df[['avg_mpg', 'price']].corr()
# Out:
#           avg_mpg     price
# avg_mpg  1.000000 -0.684201
# price   -0.684201  1.000000

# %%
plt.figure(figsize=(9,3))
sns.heatmap(df[['avg_mpg', 'price']].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.regplot(x="height", y="price", data=df)
# Out:
# <Axes: xlabel='height', ylabel='price'>

# %%
plt.figure(figsize=(9,3))
sns.heatmap(df[['height', 'price']].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
heatmap_arr = df[['symboling','normalized-losses','wheel-base','curb-weight','engine-size','bore','stroke','compression-ratio','horsepower','peak-rpm','avg_mpg','price']]
plt.figure(figsize=(12,8))
sns.heatmap(heatmap_arr.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
sns.pairplot(df)

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# The Problem: Entering a crowded automotive market or launching a new model without data-backed pricing risks undercutting profits or pricing out consumers.
#
# The Data Solution:Premium Brand Anchoring: Establish a distinct luxury tier 25,000+ using Jaguar, Mercedes-Benz, Porsche, and BMW as pricing anchors.
#
# Value-Tier Competitive Clumping: Since 12 mass-market brands (like Toyota, Honda, Nissan) tightly converge between 5,000 and 11,000, any new mass-market vehicle entry must be priced strictly within this tight corridor to remain competitive.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis reveals that vehicle pricing is systematically driven by brand status, mechanical scale, and engineering complexity:
#
# Luxury vs. Economy Segments: Jaguar, Mercedes-Benz, BMW, and Porsche anchor the high-margin premium tier, driven by rear-wheel drive (rwd) and high-cylinder engines (6, 8, and 12 cylinders).
#
# The Mass Market Floor: Chevrolet, Dodge, Honda, and Mitsubishi define the budget commuter baseline, leaning on front-wheel drive (fwd) and standard 4-cylinder engines to keep averages under $10,000.
#
# Performance Upgrades: Turbocharging (turbo) consistently commands a noticeable price premium over standard (std) aspiration across almost all consumer brands.
#
# Core Architecture: Sedans and Hatchbacks dominate overall volume, making up over 80% of the entire market dataset.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
